# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('WineQT.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
data.shape
# Out:
# (1143, 13)

# %%
plt.figure(figsize=(5,4))
sns.histplot(data['quality'], binwidth=0.4, color='g', discrete=True )
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
data1 = data.drop_duplicates()
data1.shape
# Out:
# (1143, 13)

# %%
data1.drop(['Id'], axis=1, inplace=True)
data1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
fig,axs = plt.subplots(3,4,figsize=(10,10))
p1 = sns.boxplot(data1['fixed acidity'],ax = axs[0,0])
p2 = sns.boxplot(data1['volatile acidity'],ax = axs[0,1])
p3 = sns.boxplot(data1['citric acid'],ax = axs[0,2])
p4 = sns.boxplot(data1['residual sugar'],ax = axs[0,3])
p5 = sns.boxplot(data1['chlorides'],ax = axs[1,0])
p6 = sns.boxplot(data1['free sulfur dioxide'],ax = axs[1,1])
p7 = sns.boxplot(data1['total sulfur dioxide'],ax = axs[1,2])
p8 = sns.boxplot(data1['density'],ax = axs[1,3])
p9 = sns.boxplot(data1['pH'],ax = axs[2,0])
p10 = sns.boxplot(data1['sulphates'],ax = axs[2,1])
p11 = sns.boxplot(data1['alcohol'],ax = axs[2,2])
p12 = sns.boxplot(data1['quality'],ax = axs[2,3])

plt.tight_layout()

# %%
# Create a function to remove outliers using the Interquartile Range (IQR) method
def remove_outliers(df):
    for col in df.columns:
        if df[col].dtype != 'object':  # Exclude object (string) columns
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Remove outliers from all columns
new_data = remove_outliers(data1)

# %%
new_data.shape
# Out:
# (787, 12)

# %%
chemical_qualities = new_data.drop(['quality','goodquality'], axis = 1).columns
# Create a box plot for each chemical quality
for quality in chemical_qualities:
    plt.figure(figsize=(4,3))
    sns.boxplot(x='quality', y=quality, data=new_data)
    plt.title(f'Box Plot: {quality} vs. Quality')
    plt.xlabel('Quality')
    plt.ylabel(quality)
    plt.show()

# %%
new_data['goodquality'] = [1 if x >= 7 else 0 for x in new_data['quality']]
new_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  goodquality
# 0      9.4        5            0
# ...

# %% [markdown]
# ### model building

# %%
X = new_data.drop(['quality','goodquality'], axis = 1)
Y = new_data['goodquality']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Random Forest Classifier
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
rf_predictions = rf_clf.predict(X_test)
print("Random Forest Classifier Accuracy:", accuracy_score(y_test, rf_predictions))

# Stochastic Gradient Descent Classifier
sgd_clf = SGDClassifier()
sgd_clf.fit(X_train, y_train)
sgd_predictions = sgd_clf.predict(X_test)
print("Stochastic Gradient Descent Classifier Accuracy:", accuracy_score(y_test, sgd_predictions))

# Support Vector Classifier
svc_clf = SVC()
svc_clf.fit(X_train, y_train)
svc_predictions = svc_clf.predict(X_test)
print("Support Vector Classifier Accuracy:", accuracy_score(y_test, svc_predictions))
# Out:
# Random Forest Classifier Accuracy: 0.9324894514767933
# Stochastic Gradient Descent Classifier Accuracy: 0.890295358649789
# Support Vector Classifier Accuracy: 0.890295358649789
